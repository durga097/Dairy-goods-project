# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:\\Users\\lenovo\\Downloads\\dairy_dataset.csv")
df.head(10)
# Out:
#         Location  Total Land Area (acres)  Number of Cows Farm Size  \
# 0      Telangana                   310.84              96    Medium
# 1  Uttar Pradesh                    19.19              44     Large
# 2     Tamil Nadu                   581.69              24    Medium
# 3      Telangana                   908.00              89     Small
# 4    Maharashtra                   861.95              21    Medium
# 5      Telangana                    87.64              51    Medium
# 6      Karnataka                    73.28              74     Small
# 7          Bihar                    67.61              77    Medium
# 8    West Bengal                    72.31              76    Medium
# 9      Telangana                   413.24              36     Large
#
#          Date  Product ID Product Name                 Brand  \
# 0  2022-02-17           5    Ice Cream           Dodla Dairy
# 1  2021-12-01           1         Milk                  Amul
# ...

# %% [markdown]
# # is total land area depends on number of cows

# %%
number_of_cows = np.array(df["Total Land Area (acres)"])
farm_size = np.array(df["Number of Cows"])
my_rho = np.corrcoef([number_of_cows, farm_size])
print(my_rho)
# Out:
# [[ 1.        -0.0095939]
#  [-0.0095939  1.       ]]

# %%
#with the help of uppper matrix we can say that tatal land area not depends on number of cows

# %% [markdown]
# # what is the average expiry days of each product.

# %%
group_by = df.groupby("Product Name").agg({"Shelf Life (days)":"mean"})
group_by
# Out:
#               Shelf Life (days)
# Product Name
# Butter                32.932715
# Buttermilk            10.572414
# Cheese                57.324190
# Curd                   6.025052
# Ghee                 105.741294
# Ice Cream             25.458629
# Lassi                 14.847875
# Milk                  12.923077
# Paneer                10.662132
# Yogurt                25.517162

# %% [markdown]
# # what is the average expiry days of each product.

# %%
group_by = df.groupby("Product Name").agg({"Shelf Life (days)":"mean"})
group_by
# Out:
#               Shelf Life (days)
# Product Name
# Butter                32.932715
# Buttermilk            10.572414
# Cheese                57.324190
# Curd                   6.025052
# Ghee                 105.741294
# Ice Cream             25.458629
# Lassi                 14.847875
# Milk                  12.923077
# Paneer                10.662132
# Yogurt                25.517162

# %% [markdown]
# # mention the name of the products with max and min shelf life

# %%
high_shelf_life = df["Shelf Life (days)"].idxmax()
high_shelf_life
# Out:
# 875

# %%
low_shelf_life = df["Shelf Life (days)"].idxmin()
low_shelf_life
# Out:
# 15

# %% [markdown]
# # summarize the data on the basis of brands and land acquired by them,cows and the revenue generated by them.

# %%
group_by = df.groupby(['Brand']).agg({"Total Land Area (acres)":"sum","Number of Cows":"sum", "Approx. Total Revenue(INR)":"sum"})
group_by
# Out:
#                       Total Land Area (acres)  Number of Cows  \
# Brand
# Amul                                528377.46           56873
# Britannia Industries                 51221.94            4968
# Dodla Dairy                         111974.65           12354
# Dynamix Dairies                      55356.87            5637
# Mother Dairy                        497118.15           56517
# Palle2patnam                        106237.70           11705
# Parag Milk Foods                     53690.47            5204
# Passion Cheese                       50724.93            5353
# Raj                                 346073.91           36957
# Sudha                               328411.07           36467
# Warana                               48377.14            5683
#
#                       Approx. Total Revenue(INR)
# Brand
# Amul                                 14608864.46
# Britannia Industries                  1029522.05
# Dodla Dairy                           2604857.37
# ...

# %% [markdown]
# # What is the average shelf life for different storage conditions.

# %%
group_by = df.groupby(["Brand","Product Name","Storage Condition"]).agg({"Shelf Life (days)":"mean"})
group_by
# Out:
#                                                      Shelf Life (days)
# Brand                Product Name Storage Condition
# Amul                 Butter       Frozen                     33.679245
#                                   Refrigerated               32.018182
#                      Buttermilk   Refrigerated               11.044944
#                      Cheese       Frozen                     58.387755
#                                   Refrigerated               58.080645
#                      Curd         Refrigerated                6.099174
#                      Ghee         Ambient                   105.105263
#                      Ice Cream    Frozen                     25.283019
#                      Lassi        Refrigerated               14.888889
#                      Milk         Polythene Packet            1.471698
#                                   Tetra Pack                 25.565217
# ...
